# %% [markdown]
# <a href="https://colab.research.google.com/github/Eseose/Hamoye-HDSC-21/blob/master/HDSC22_MLPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the link to the GIThub repo.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
len(df['Area'].unique())
# Out:
# 49

# %%
df_Algeria = df[df['Area']=='Algeria']
df_Algeria.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df_Algeria[df_Algeria['Element']=='Import Quantity']['Y2018'].sum()
# Out:
# 36238.29

# %%
df_animal_fats = df[df['Item'] == 'Animal fats']
df_animal_fats
# Out:
#        Area Code      Area  Item Code         Item  Element Code  \
# 1057           4   Algeria       2946  Animal fats          5511
# 1058           4   Algeria       2946  Animal fats          5611
# 1059           4   Algeria       2946  Animal fats          5072
# 1060           4   Algeria       2946  Animal fats          5911
# 1061           4   Algeria       2946  Animal fats          5301
# ...          ...       ...        ...          ...           ...
# 60697        181  Zimbabwe       2946  Animal fats          5142
# 60698        181  Zimbabwe       2946  Animal fats           645
# 60699        181  Zimbabwe       2946  Animal fats           664
# 60700        181  Zimbabwe       2946  Animal fats           674
# 60701        181  Zimbabwe       2946  Animal fats           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 1057                               Production      1000 tonnes  18.00  17.00
# ...

# %%
df_animal_fats['Y2014'].sum()
# Out:
# 209460.54

# %%
df_animal_fats['Y2017'].sum()
# Out:
# 269617.53

# %%
df['Y2015'].std()
# Out:
# 1603.4039839425013

# %%
df['Y2015'].mean()
# Out:
# 135.23596649549626

# %%
df['Y2016'].isna().sum()
# Out:
# 1535

# %%
(df['Y2016'].isna().sum())/(df['Y2016'].count())*100
# Out:
# 2.583827093994075

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df_2 = df_Algeria[df_Algeria['Element'] == 'Import Quantity']

# %%
df_2.sum()
# Out:
# Area Code                                                     448
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                  301030
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                               628432
# Element         Import QuantityImport QuantityImport QuantityI...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                    34940.12
# Y2015                                                    37841.91
# Y2016                                                    36736.08
# Y2017                                                    36059.29
# Y2018                                                    36238.29
# dtype: object

# %%
df[df["Element"] == 'Import Quantity'].sum()
# Out:
# Area Code                                                  688174
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                13795966
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                             28834929
# Element         Import QuantityImport QuantityImport QuantityI...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                   274144.48
# Y2015                                                   267018.46
# Y2016                                                   286582.78
# Y2017                                                   294559.09
# Y2018                                                   287997.09
# dtype: object

# %%
df[df['Element']=='Production']['Y2014'].sum()
# Out:
# 1931287.75

# %%
df.groupby('Element')['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
for i in range(1,4):
  print(i)
# Out:
# 1
# 2
# 3
